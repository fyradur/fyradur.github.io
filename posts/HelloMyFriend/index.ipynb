# %% [raw]
# ---
# title: "Hello my friend"
# format: html
# author: "John Möller"
# date: "2024-01-31"
# categories: [, code, analysis]
# draft: true
# ---

# %%
print("Hello friends!")
# Out:
# Hello friends!
